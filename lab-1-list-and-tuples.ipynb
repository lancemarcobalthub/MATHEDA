# %% [markdown]
# # List and Tuples <hr style="border:2.5px solid #82127cff"></hr>

# %% [markdown]
# <b>Lance Marco F. Baltazar</b>
# <br>TUPV Computer Engineering CpE-2A

# %% [markdown]
# # Creating a List

# %%
numbers = [1,2,3,4,5]

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
type(numbers)
# Out:
# list

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
mixed_list = [10,'hello',2.5,True]
mixed_list
# Out:
# [10, 'hello', 2.5, True]

# %% [markdown]
# # Indexing

# %%
numbers = [1,2,3,4,5]

# %%
numbers[0]
# Out:
# 1

# %%
numbers[4]
# Out:
# 5

# %%
numbers[-1]
# Out:
# 5

# %% [markdown]
# # Modifying Elements

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'apple' in fruits
# Out:
# True

# %%
fruits[0] = 'orange'
fruits
# Out:
# ['orange', 'banana', 'grape']

# %%
'apple' in fruits
# Out:
# False

# %% [markdown]
# # Adding Elements

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
fruits.append('orange')
fruits
# Out:
# ['apple', 'banana', 'grape', 'orange']

# %%
fruits.insert(1, 'blueberry')
fruits
# Out:
# ['apple', 'blueberry', 'banana', 'grape', 'orange']

# %% [markdown]
# # Removing Elements

# %%
fruits = ['apple','banana','grape']
fruits
# Out:
# ['apple', 'banana', 'grape']

# %%
'banana' in fruits
# Out:
# True

# %%
fruits.remove('banana')

# %%
fruits
# Out:
# ['apple', 'grape']

# %%
fruits.pop(0)
# Out:
# 'apple'

# %% [markdown]
# # Sort() and Sorted()

# %%
numbers = [3,1,5,4,2]
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
sorted(numbers,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
numbers
# Out:
# [3, 1, 5, 4, 2]

# %%
numbers.sort(reverse=True)

# %% [markdown]
# # Slicing

# %%
chars = ['a','b','c','x','y']
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
len(chars)
# Out:
# 5

# %%
sub = chars[1:4]

# %%
sub
# Out:
# ['b', 'c', 'x']

# %%
chars
# Out:
# ['a', 'b', 'c', 'x', 'y']

# %%
chars[0:5:2]
# Out:
# ['a', 'c', 'y']

# %% [markdown]
# # Tuple

# %%
my_tuple = (1,2,3,4,5)
my_tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
type(my_tuple)
# Out:
# tuple

# %%
len(my_tuple)
# Out:
# 5

# %%
my_tuple[2]
# Out:
# 3

# %%
my_tuple[1:3]
# Out:
# (2, 3)

# %%
my_tuple[0] = 1
# sample error changing my_tuple object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 my_tuple[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple = (2,2,3,4,5)

# %%
my_tuple
# Out:
# (2, 2, 3, 4, 5)

# %%
mixed_tuple = (10,'hello',2.5,True)
mixed_tuple
# Out:
# (10, 'hello', 2.5, True)
